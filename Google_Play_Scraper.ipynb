# %% [markdown]
# # Install Library

# %%
pip install google-play-scraper
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %% [markdown]
# # Import Library

# %%
from google_play_scraper import app

import pandas as pd
import numpy as np

# %% [markdown]
# # Showing Review based on number of review we want to show.
# you also can set the parameter you desire, such as language, country, and etc

# %%
from google_play_scraper import Sort, reviews

result, continuation_token = reviews(
    'com.fantome.penguinisle',
    lang='en', # defaults to 'en'
    country='us', # defaults to 'us'
    sort=Sort.NEWEST, # defaults to Sort.NEWEST
    count=3, # defaults to 100
    filter_score_with=5 # defaults to None(means all score)
)

# If you pass `continuation_token` as an argument to the reviews function at this point,
# it will crawl the items after 3 review items.

result, _ = reviews(
    'com.fantome.penguinisle',
    continuation_token=continuation_token # defaults to None(load from the beginning)
)

result
# Out:
# [{'reviewId': 'b2d1931d-ee73-443e-b963-2ef62c30162f',
#   'userName': 'Emeris Pendragon',
#   'userImage': 'https://play-lh.googleusercontent.com/a/AItbvmkwnO_tvYWsM82aup7eXjOxdSPe562eJ74qtum_=mo',
#   'content': 'Relaxing and fun game',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '1.49.1',
#   'at': datetime.datetime(2022, 8, 22, 3, 48, 57),
#   'replyContent': None,
#   'repliedAt': None},
#  {'reviewId': 'b44bc5fc-0dce-44c7-8a7b-631523236299',
#   'userName': 'Parsa Mahmoodzade',
#   'userImage': 'https://play-lh.googleusercontent.com/a/AItbvmnn3upTsBpATRTHEKoWFSOEarhZ8gwGhpCtjoGF=mo',
#   'content': 'really enjoy it🙏',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '1.49.1',
#   'at': datetime.datetime(2022, 8, 21, 16, 56, 15),
#   'replyContent': None,
#   'repliedAt': None},
#  {'reviewId': 'da828288-a8ac-44c7-b014-34c576da941a',
#   'userName': 'UJIN KIM',
# ...

# %% [markdown]
# # Show ALL reviews

# %%
from google_play_scraper import Sort, reviews_all

result = reviews_all(
    'com.fantome.penguinisle',
    sleep_milliseconds=0, # defaults to 0
    lang='en', # defaults to 'en'
    country='us', # defaults to 'us'
    sort=Sort.MOST_RELEVANT, # defaults to Sort.MOST_RELEVANT
    filter_score_with=5 # defaults to None(means all score)
)

result
# Out:
# [{'reviewId': 'fb567124-3ad2-4145-b44f-861bd937193c',
#   'userName': 'Kailey E. Reyes',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AFdZucoGQypct8PB_2lk4Xo-TB3DzI3NkeFVZM4rdFmvJro',
#   'content': "This game is amazing! Everytime I click on to get a bonus or more coins to watch an ad, it's doesn't give me any ads, it just gives me the bonus or the coins!! Definitely one of my favorite games on the app store! It's calming and cute! I love unlocking creature and adding furniture and new islands!! It's so cute! I love this game! It gives me happy feet vibes! The penguins are so adorable too!! It kept me hooked for hours! 🔥",
#   'score': 5,
#   'thumbsUpCount': 69,
#   'reviewCreatedVersion': '1.44.0',
#   'at': datetime.datetime(2022, 3, 28, 22, 37, 1),
#   'replyContent': None,
#   'repliedAt': None},
#  {'reviewId': '8364b3a1-45a9-42ac-8e7a-a575db82fb45',
#   'userName': 'Kelly Edgar',
# ...

# %% [markdown]
# # Make review into pandas data frame

# %%
df_review = pd.DataFrame(np.array(result),columns=['review'])

df_review = df_busu.join(pd.DataFrame(df_busu.pop('review').tolist()))

df_review.head()
# Out:
#                                reviewId         userName  \
# 0  fb567124-3ad2-4145-b44f-861bd937193c  Kailey E. Reyes
# 1  8364b3a1-45a9-42ac-8e7a-a575db82fb45      Kelly Edgar
# 2  793226de-e6cf-439f-8ea8-ea6b1f6afc9e        Livia Way
# 3  d12d8150-ea14-453a-8096-26851e557a9b     Morgan Ellis
# 4  ba2c136c-b800-47f3-857c-8beb6ded51bf    A Google user
#
#                                            userImage  \
# 0  https://play-lh.googleusercontent.com/a-/AFdZu...
# 1  https://play-lh.googleusercontent.com/a/AItbvm...
# 2  https://play-lh.googleusercontent.com/a-/AFdZu...
# 3  https://play-lh.googleusercontent.com/a-/AFdZu...
# 4  https://play-lh.googleusercontent.com/EGemoI2N...
#
#                                              content  score  thumbsUpCount  \
# 0  This game is amazing! Everytime I click on to ...      5             69
# 1  If you're looking for a true idle app that doe...      5              3
# ...
